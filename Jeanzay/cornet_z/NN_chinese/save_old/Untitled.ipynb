# %%
import numpy as np
import matplotlib.pyplot as plt
xx = np.load('cat_scores_lit_no_bias_z_full_nomir.npy')

# %%
plt.plot(np.mean(xx[:,:1000],1))
plt.plot(np.mean(xx[:,1000:],1))
plt.ylim([0,100])
# Out:
# (0.0, 100.0)
