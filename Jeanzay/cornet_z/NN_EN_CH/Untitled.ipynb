# %%
from stimgen import CreateWordSet
CreateWordSet()

# %%
from clean_train_local import train
train()

# %%
import numpy as np
words_en = np.load('Ewordlist.npy')
words_en = words_en[1::2]
(words_en)

# %%
import numpy as np
import matplotlib.pyplot as plt
xx=  np.load('models/cat_scores_lit_no_bias_z_full_nomir.npy')
plt.plot(np.mean(xx[:,:1000],1))
plt.plot(np.mean(xx[:,1000:1500],1))
plt.plot(np.mean(xx[:,1500:],1))

# %%
xx=  np.load('models/valloss_lit_no_bias_z_full_nomir.npy')
plt.plot(xx)
